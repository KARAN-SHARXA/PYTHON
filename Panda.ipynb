# %%
import pandas as pd

# %%
# to_csv("file name")
#read_csv("file name")
data = {
    "Name": ["Karan", "Pinku", "Akash", "Tejas"],
    "Age": [21, 22, 20, 21],
    "City": ["Kangra", "Baddi", "Shimla", "Baddi"]
}

df = pd.DataFrame(data)
print(df)
df.to_csv("students_data.csv")
pd.read_csv("students_data.csv")
# Out:
#     Name  Age    City
# 0  Karan   21  Kangra
# 1  Pinku   22   Baddi
# 2  Akash   20  Shimla
# 3  Tejas   21   Baddi
#    Unnamed: 0   Name  Age    City
# 0           0  Karan   21  Kangra
# 1           1  Pinku   22   Baddi
# 2           2  Akash   20  Shimla
# 3           3  Tejas   21   Baddi

# %%
import pandas as pd

data1 = {
    "Date": ["2025-07-01", "2025-07-01", "2025-07-01", "2025-07-02", "2025-07-02", "2025-07-03", "2025-07-03", "2025-07-03"],
    "Product": ["Laptop", "Headphones", "Smartphone", "Laptop", "Mouse", "Keyboard", "Smartphone", "Power Bank"],
    "Category": ["Electronics", "Accessories", "Electronics", "Electronics", "Accessories", "Accessories", "Electronics", "Accessories"],
    "Units_Sold": [5, 15, 8, 3, 20, 12, 10, 18],
    "Unit_Price": [55000, 1500, 30000, 55000, 500, 800, 30000, 1200],
    "Total_Sales": [275000, 22500, 240000, 165000, 10000, 9600, 300000, 21600],
    "City": ["Delhi", "Mumbai", "Bangalore", "Chennai", "Delhi", "Mumbai", "Bangalore", "Kolkata"]
}

bf = pd.DataFrame(data1)
print(bf)
bf.to_csv("company.csv")
pd.read_csv("company.csv")
# Out:
#          Date     Product     Category  Units_Sold  Unit_Price  Total_Sales  \
# 0  2025-07-01      Laptop  Electronics           5       55000       275000
# 1  2025-07-01  Headphones  Accessories          15        1500        22500
# 2  2025-07-01  Smartphone  Electronics           8       30000       240000
# 3  2025-07-02      Laptop  Electronics           3       55000       165000
# 4  2025-07-02       Mouse  Accessories          20         500        10000
# 5  2025-07-03    Keyboard  Accessories          12         800         9600
# 6  2025-07-03  Smartphone  Electronics          10       30000       300000
# 7  2025-07-03  Power Bank  Accessories          18        1200        21600
#
#         City
# 0      Delhi
# 1     Mumbai
# 2  Bangalore
# 3    Chennai
# 4      Delhi
# 5     Mumbai
# 6  Bangalore
# 7    Kolkata
#    Unnamed: 0        Date     Product     Category  Units_Sold  Unit_Price  \
# 0           0  2025-07-01      Laptop  Electronics           5       55000
# ...

# %%
pd.read_csv("company.csv")
# Out:
#    Unnamed: 0        Date     Product     Category  Units_Sold  Unit_Price  \
# 0           0  2025-07-01      Laptop  Electronics           5       55000
# 1           1  2025-07-01  Headphones  Accessories          15        1500
# 2           2  2025-07-01  Smartphone  Electronics           8       30000
# 3           3  2025-07-02      Laptop  Electronics           3       55000
# 4           4  2025-07-02       Mouse  Accessories          20         500
# 5           5  2025-07-03    Keyboard  Accessories          12         800
# 6           6  2025-07-03  Smartphone  Electronics          10       30000
# 7           7  2025-07-03  Power Bank  Accessories          18        1200
#
#    Total_Sales       City
# 0       275000      Delhi
# 1        22500     Mumbai
# 2       240000  Bangalore
# 3       165000    Chennai
# 4        10000      Delhi
# 5         9600     Mumbai
# 6       300000  Bangalore
# 7        21600    Kolkata

# %%
df.head()
# Out:
#     Name  Age    City
# 0  Karan   21  Kangra
# 1  Pinku   22   Baddi
# 2  Akash   20  Shimla
# 3  Tejas   21   Baddi

# %%
df.tail()
# Out:
#     Name  Age    City
# 0  Karan   21  Kangra
# 1  Pinku   22   Baddi
# 2  Akash   20  Shimla
# 3  Tejas   21   Baddi

# %%
df.dtypes
# Out:
# Name    object
# Age      int64
# City    object
# dtype: object

# %%
df.describe()
# Out:
#              Age
# count   4.000000
# mean   21.000000
# std     0.816497
# min    20.000000
# 25%    20.750000
# 50%    21.000000
# 75%    21.250000
# max    22.000000

# %%
df[['Name','Age']]
# Out:
#     Name  Age
# 0  Karan   21
# 1  Pinku   22
# 2  Akash   20
# 3  Tejas   21

# %%
df.dtypes == "object"
# Out:
# Name     True
# Age     False
# City     True
# dtype: bool

# %%
df.dtypes == "float64"
# Out:
# Name    False
# Age     False
# City    False
# dtype: bool

# %%
df.dtypes == "int64"
# Out:
# Name    False
# Age      True
# City    False
# dtype: bool

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
df[['Age']]
# Out:
#    Age
# 0   21
# 1   22
# 2   20
# 3   21

# %%
df[["Age"]][0:2]
# Out:
#    Age
# 0   21
# 1   22

# %%
df[['Age',"Name"]]
# Out:
#    Age   Name
# 0   21  Karan
# 1   22  Pinku
# 2   20  Akash
# 3   21  Tejas

# %%
df["new_col"]=0,1,2,3

# %%
df
# Out:
#     Name  Age    City  new_col
# 0  Karan   21  Kangra        0
# 1  Pinku   22   Baddi        1
# 2  Akash   20  Shimla        2
# 3  Tejas   21   Baddi        3

# %%
df.insert(loc = 1,column='food',value=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24268\1541438567.py in ?()
# ----> 1 df.insert(loc = 1,column='food',value=0)
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5154                 "'self.flags.allows_duplicate_labels' is False."
#    5155             )
#    5156         if not allow_duplicates and column in self.columns:
#    5157             # Should this be a different kind of error??
# -> 5158             raise ValueError(f"cannot insert {column}, already exists")
#    5159         if not is_integer(loc):
#    5160             raise TypeError("loc must be int")
#    5161         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert food, already exists

# %%
df
# Out:
#     Name  food  Age    City  new_col
# 0  Karan     0   21  Kangra        0
# 1  Pinku     0   22   Baddi        1
# 2  Akash     0   20  Shimla        2
# 3  Tejas     0   21   Baddi        3

# %%
import pandas as pd
pd.read_csv("large_dataset_for_cleaning.csv")
# Out:
#     Order_ID Customer_Name  Gender       City     Product     Category  \
# 0    ORD1000    Customer_0   Other  Hyderabad      Camera      Gadgets
# 1    ORD1001    Customer_1    Male    Chennai      Camera  Accessories
# 2    ORD1002    Customer_2    Male  Hyderabad    Keyboard      Gadgets
# 3    ORD1003    Customer_3   Other  Ahmedabad      Laptop  Electronics
# 4    ORD1004    Customer_4  Female  Ahmedabad  Headphones  Electronics
# ..       ...           ...     ...        ...         ...          ...
# 995  ORD1995  Customer_995   Other    Chennai     Monitor      Gadgets
# 996  ORD1996  Customer_996  Female       Pune    Keyboard  Electronics
# 997  ORD1997  Customer_997    Male      Delhi  Smartphone      Gadgets
# 998  ORD1998  Customer_998    Male      Delhi     Monitor      Gadgets
# 999  ORD1999  Customer_999    Male    Kolkata  Smartphone  Electronics
#
#         Price  Quantity Purchase_Date Payment_Mode
# 0     6596.52         1    2023-01-01       Wallet
# ...

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

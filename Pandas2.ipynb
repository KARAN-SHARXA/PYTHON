# %%
import pandas as pd
df=pd.read_csv("large_dataset_for_cleaning.csv")

# %%
df
# Out:
#     Order_ID Customer_Name  Gender       City     Product     Category  \
# 0    ORD1000    Customer_0   Other  Hyderabad      Camera      Gadgets
# 1    ORD1001    Customer_1    Male    Chennai      Camera  Accessories
# 2    ORD1002    Customer_2    Male  Hyderabad    Keyboard      Gadgets
# 3    ORD1003    Customer_3   Other  Ahmedabad      Laptop  Electronics
# 4    ORD1004    Customer_4  Female  Ahmedabad  Headphones  Electronics
# ..       ...           ...     ...        ...         ...          ...
# 995  ORD1995  Customer_995   Other    Chennai     Monitor      Gadgets
# 996  ORD1996  Customer_996  Female       Pune    Keyboard  Electronics
# 997  ORD1997  Customer_997    Male      Delhi  Smartphone      Gadgets
# 998  ORD1998  Customer_998    Male      Delhi     Monitor      Gadgets
# 999  ORD1999  Customer_999    Male    Kolkata  Smartphone  Electronics
#
#         Price  Quantity Purchase_Date Payment_Mode
# 0     6596.52         1    2023-01-01       Wallet
# ...

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_Name', 'Gender', 'City', 'Product', 'Category',
#        'Price', 'Quantity', 'Purchase_Date', 'Payment_Mode'],
#       dtype='object')

# %%
df['Customer_Name']
# Out:
# 0        Customer_0
# 1        Customer_1
# 2        Customer_2
# 3        Customer_3
# 4        Customer_4
#            ...
# 995    Customer_995
# 996    Customer_996
# 997    Customer_997
# 998    Customer_998
# 999    Customer_999
# Name: Customer_Name, Length: 1000, dtype: object

# %%
a=df[['Customer_Name']][0:10]
print(a)
# Out:
#   Customer_Name
# 0    Customer_0
# 1    Customer_1
# 2    Customer_2
# 3    Customer_3
# 4    Customer_4
# 5    Customer_5
# 6    Customer_6
# 7    Customer_7
# 8    Customer_8
# 9    Customer_9

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
m1=pd.Series([100,200,300,400,500],index=[1,2,3,4,5])
print(m1)
# Out:
# 1    100
# 2    200
# 3    300
# 4    400
# 5    500
# dtype: int64

# %%
m2=pd.Series([600,500,44000,33,33],index=[1,2,3,4,5])
print(m2)
# Out:
# 1      600
# 2      500
# 3    44000
# 4       33
# 5       33
# dtype: int64

# %%
m3=pd.concat([m1,m2])
m3
# Out:
# 1      100
# 2      200
# 3      300
# 4      400
# 5      500
# 1      600
# 2      500
# 3    44000
# 4       33
# 5       33
# dtype: int64

# %%
m3[1]
# Out:
# 1    100
# 1    600
# dtype: int64

# %%
df.head()
# Out:
#   Order_ID Customer_Name  Gender       City     Product     Category  \
# 0  ORD1000    Customer_0   Other  Hyderabad      Camera      Gadgets
# 1  ORD1001    Customer_1    Male    Chennai      Camera  Accessories
# 2  ORD1002    Customer_2    Male  Hyderabad    Keyboard      Gadgets
# 3  ORD1003    Customer_3   Other  Ahmedabad      Laptop  Electronics
# 4  ORD1004    Customer_4  Female  Ahmedabad  Headphones  Electronics
#
#       Price  Quantity Purchase_Date Payment_Mode
# 0   6596.52         1    2023-01-01       Wallet
# 1  35699.95         5    2023-01-02          UPI
# 2       NaN         3    2023-01-03       Wallet
# 3  19072.03         2    2023-01-04         Cash
# 4  32195.89         4    2023-01-05         Cash

# %%
df.drop("Gender",axis=1 #,inplace=true(permanent true))
# Out:
#     Order_ID Customer_Name       City     Product     Category     Price  \
# 0    ORD1000    Customer_0  Hyderabad      Camera      Gadgets   6596.52
# 1    ORD1001    Customer_1    Chennai      Camera  Accessories  35699.95
# 2    ORD1002    Customer_2  Hyderabad    Keyboard      Gadgets       NaN
# 3    ORD1003    Customer_3  Ahmedabad      Laptop  Electronics  19072.03
# 4    ORD1004    Customer_4  Ahmedabad  Headphones  Electronics  32195.89
# ..       ...           ...        ...         ...          ...       ...
# 995  ORD1995  Customer_995    Chennai     Monitor      Gadgets  37895.90
# 996  ORD1996  Customer_996       Pune    Keyboard  Electronics       NaN
# 997  ORD1997  Customer_997      Delhi  Smartphone      Gadgets       NaN
# 998  ORD1998  Customer_998      Delhi     Monitor      Gadgets  39999.26
# 999  ORD1999  Customer_999    Kolkata  Smartphone  Electronics  30051.69
#
#      Quantity Purchase_Date Payment_Mode
# 0           1    2023-01-01       Wallet
# ...

# %%
df.head()
# Out:
#   Order_ID Customer_Name  Gender       City     Product     Category  \
# 0  ORD1000    Customer_0   Other  Hyderabad      Camera      Gadgets
# 1  ORD1001    Customer_1    Male    Chennai      Camera  Accessories
# 2  ORD1002    Customer_2    Male  Hyderabad    Keyboard      Gadgets
# 3  ORD1003    Customer_3   Other  Ahmedabad      Laptop  Electronics
# 4  ORD1004    Customer_4  Female  Ahmedabad  Headphones  Electronics
#
#       Price  Quantity Purchase_Date Payment_Mode
# 0   6596.52         1    2023-01-01       Wallet
# 1  35699.95         5    2023-01-02          UPI
# 2       NaN         3    2023-01-03       Wallet
# 3  19072.03         2    2023-01-04         Cash
# 4  32195.89         4    2023-01-05         Cash

# %%
df.drop(3)
# Out:
#     Order_ID Customer_Name  Gender       City     Product     Category  \
# 0    ORD1000    Customer_0   Other  Hyderabad      Camera      Gadgets
# 1    ORD1001    Customer_1    Male    Chennai      Camera  Accessories
# 2    ORD1002    Customer_2    Male  Hyderabad    Keyboard      Gadgets
# 4    ORD1004    Customer_4  Female  Ahmedabad  Headphones  Electronics
# 5    ORD1005    Customer_5    Male    Kolkata     Charger  Accessories
# ..       ...           ...     ...        ...         ...          ...
# 995  ORD1995  Customer_995   Other    Chennai     Monitor      Gadgets
# 996  ORD1996  Customer_996  Female       Pune    Keyboard  Electronics
# 997  ORD1997  Customer_997    Male      Delhi  Smartphone      Gadgets
# 998  ORD1998  Customer_998    Male      Delhi     Monitor      Gadgets
# 999  ORD1999  Customer_999    Male    Kolkata  Smartphone  Electronics
#
#         Price  Quantity Purchase_Date Payment_Mode
# 0     6596.52         1    2023-01-01       Wallet
# ...

# %%
df
# Out:
#     Order_ID Customer_Name  Gender       City     Product     Category  \
# 0    ORD1000    Customer_0   Other  Hyderabad      Camera      Gadgets
# 1    ORD1001    Customer_1    Male    Chennai      Camera  Accessories
# 2    ORD1002    Customer_2    Male  Hyderabad    Keyboard      Gadgets
# 3    ORD1003    Customer_3   Other  Ahmedabad      Laptop  Electronics
# 4    ORD1004    Customer_4  Female  Ahmedabad  Headphones  Electronics
# ..       ...           ...     ...        ...         ...          ...
# 995  ORD1995  Customer_995   Other    Chennai     Monitor      Gadgets
# 996  ORD1996  Customer_996  Female       Pune    Keyboard  Electronics
# 997  ORD1997  Customer_997    Male      Delhi  Smartphone      Gadgets
# 998  ORD1998  Customer_998    Male      Delhi     Monitor      Gadgets
# 999  ORD1999  Customer_999    Male    Kolkata  Smartphone  Electronics
#
#         Price  Quantity Purchase_Date Payment_Mode
# 0     6596.52         1    2023-01-01       Wallet
# ...

# %%
df
# Out:
#        Order_ID Customer_Name       City     Product     Category     Price  \
# Gender
# Other   ORD1000    Customer_0  Hyderabad      Camera      Gadgets   6596.52
# Male    ORD1001    Customer_1    Chennai      Camera  Accessories  35699.95
# Male    ORD1002    Customer_2  Hyderabad    Keyboard      Gadgets       NaN
# Other   ORD1003    Customer_3  Ahmedabad      Laptop  Electronics  19072.03
# Female  ORD1004    Customer_4  Ahmedabad  Headphones  Electronics  32195.89
# ...         ...           ...        ...         ...          ...       ...
# Other   ORD1995  Customer_995    Chennai     Monitor      Gadgets  37895.90
# Female  ORD1996  Customer_996       Pune    Keyboard  Electronics       NaN
# Male    ORD1997  Customer_997      Delhi  Smartphone      Gadgets       NaN
# Male    ORD1998  Customer_998      Delhi     Monitor      Gadgets  39999.26
# Male    ORD1999  Customer_999    Kolkata  Smartphone  Electronics  30051.69
#
#         Quantity Purchase_Date Payment_Mode
# ...

# %%
df.set_index('Name',inplace=true)

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#      level_0  index  Gender Order_ID Customer_Name       City     Product  \
# 0          0      0   Other  ORD1000    Customer_0  Hyderabad      Camera
# 1          1      1    Male  ORD1001    Customer_1    Chennai      Camera
# 2          2      2    Male  ORD1002    Customer_2  Hyderabad    Keyboard
# 3          3      3   Other  ORD1003    Customer_3  Ahmedabad      Laptop
# 4          4      4  Female  ORD1004    Customer_4  Ahmedabad  Headphones
# ..       ...    ...     ...      ...           ...        ...         ...
# 995      995    995   Other  ORD1995  Customer_995    Chennai     Monitor
# 996      996    996  Female  ORD1996  Customer_996       Pune    Keyboard
# 997      997    997    Male  ORD1997  Customer_997      Delhi  Smartphone
# 998      998    998    Male  ORD1998  Customer_998      Delhi     Monitor
# 999      999    999    Male  ORD1999  Customer_999    Kolkata  Smartphone
#
#         Category     Price  Quantity Purchase_Date Payment_Mode
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      level_0  index  Gender Order_ID Customer_Name       City     Product  \
# 0          0      0   Other  ORD1000    Customer_0  Hyderabad      Camera
# 1          1      1    Male  ORD1001    Customer_1    Chennai      Camera
# 3          3      3   Other  ORD1003    Customer_3  Ahmedabad      Laptop
# 4          4      4  Female  ORD1004    Customer_4  Ahmedabad  Headphones
# 5          5      5    Male  ORD1005    Customer_5    Kolkata     Charger
# ..       ...    ...     ...      ...           ...        ...         ...
# 993      993    993    Male  ORD1993  Customer_993  Ahmedabad  Smartphone
# 994      994    994    Male  ORD1994  Customer_994    Chennai      Camera
# 995      995    995   Other  ORD1995  Customer_995    Chennai     Monitor
# 998      998    998    Male  ORD1998  Customer_998      Delhi     Monitor
# 999      999    999    Male  ORD1999  Customer_999    Kolkata  Smartphone
#
#         Category     Price  Quantity Purchase_Date Payment_Mode
# ...

# %%
df1=pd.read_csv("large_dataset_for_cleaning.csv")

# %%
df1
# Out:
#     Order_ID Customer_Name  Gender       City     Product     Category  \
# 0    ORD1000    Customer_0   Other  Hyderabad      Camera      Gadgets
# 1    ORD1001    Customer_1    Male    Chennai      Camera  Accessories
# 2    ORD1002    Customer_2    Male  Hyderabad    Keyboard      Gadgets
# 3    ORD1003    Customer_3   Other  Ahmedabad      Laptop  Electronics
# 4    ORD1004    Customer_4  Female  Ahmedabad  Headphones  Electronics
# ..       ...           ...     ...        ...         ...          ...
# 995  ORD1995  Customer_995   Other    Chennai     Monitor      Gadgets
# 996  ORD1996  Customer_996  Female       Pune    Keyboard  Electronics
# 997  ORD1997  Customer_997    Male      Delhi  Smartphone      Gadgets
# 998  ORD1998  Customer_998    Male      Delhi     Monitor      Gadgets
# 999  ORD1999  Customer_999    Male    Kolkata  Smartphone  Electronics
#
#         Price  Quantity Purchase_Date Payment_Mode
# 0     6596.52         1    2023-01-01       Wallet
# ...

# %%
df1.dropna(axis=1)
# Out:
#     Order_ID  Gender       City     Product     Category  Quantity  \
# 0    ORD1000   Other  Hyderabad      Camera      Gadgets         1
# 1    ORD1001    Male    Chennai      Camera  Accessories         5
# 2    ORD1002    Male  Hyderabad    Keyboard      Gadgets         3
# 3    ORD1003   Other  Ahmedabad      Laptop  Electronics         2
# 4    ORD1004  Female  Ahmedabad  Headphones  Electronics         4
# ..       ...     ...        ...         ...          ...       ...
# 995  ORD1995   Other    Chennai     Monitor      Gadgets         1
# 996  ORD1996  Female       Pune    Keyboard  Electronics         4
# 997  ORD1997    Male      Delhi  Smartphone      Gadgets         4
# 998  ORD1998    Male      Delhi     Monitor      Gadgets         2
# 999  ORD1999    Male    Kolkata  Smartphone  Electronics         5
#
#     Purchase_Date Payment_Mode
# 0      2023-01-01       Wallet
# 1      2023-01-02          UPI
# 2      2023-01-03       Wallet
# 3      2023-01-04         Cash
# ...

# %%
df1.fillna("karan")
# Out:
#     Order_ID Customer_Name  Gender       City     Product     Category  \
# 0    ORD1000    Customer_0   Other  Hyderabad      Camera      Gadgets
# 1    ORD1001    Customer_1    Male    Chennai      Camera  Accessories
# 2    ORD1002    Customer_2    Male  Hyderabad    Keyboard      Gadgets
# 3    ORD1003    Customer_3   Other  Ahmedabad      Laptop  Electronics
# 4    ORD1004    Customer_4  Female  Ahmedabad  Headphones  Electronics
# ..       ...           ...     ...        ...         ...          ...
# 995  ORD1995  Customer_995   Other    Chennai     Monitor      Gadgets
# 996  ORD1996  Customer_996  Female       Pune    Keyboard  Electronics
# 997  ORD1997  Customer_997    Male      Delhi  Smartphone      Gadgets
# 998  ORD1998  Customer_998    Male      Delhi     Monitor      Gadgets
# 999  ORD1999  Customer_999    Male    Kolkata  Smartphone  Electronics
#
#         Price  Quantity Purchase_Date Payment_Mode
# 0     6596.52         1    2023-01-01       Wallet
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\karan\\DATA_ANALYTICS'
